# %%
# test change 11 March 2021
from preprocessing import *

# %% [markdown]
# # 1. load data

# %%
mnist5_x_train, mnist5_y_train, mnist5_x_test, mnist5_y_test = load_data("FashionMNIST0.5.npz")
mnist6_x_train, mnist6_y_train, mnist6_x_test, mnist6_y_test = load_data("FashionMNIST0.6.npz")
cifer_x_train, cifer_y_train, cifer_x_test, cifer_y_test = load_data('CIFAR.npz')

# %% [markdown]
# # 2. visualization

# %%
show_data(mnist5_x_train, mnist5_y_train)

# %%
show_data(mnist6_x_train, mnist6_y_train)

# %%
show_data(cifer_x_train, cifer_y_train)

# %% [markdown]
# # 3. Dimensionality reduction with auto-encoder , t-SNE, UAMP
